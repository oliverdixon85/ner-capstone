# %%
! pip install transformers
! pip install simpletransformers
# Out:
# ...
#      |████████████████████████████████| 3.5 MB 4.3 MB/s
# ...
#      |████████████████████████████████| 6.8 MB 32.8 MB/s
# ...
#      |████████████████████████████████| 67 kB 3.7 MB/s
# ...
#      |████████████████████████████████| 596 kB 45.9 MB/s
# ...
#      |████████████████████████████████| 895 kB 49.9 MB/s
# ...
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# ...
#      |████████████████████████████████| 248 kB 4.2 MB/s
# ...
#      |████████████████████████████████| 311 kB 56.8 MB/s
# ...
#      |████████████████████████████████| 1.2 MB 61.9 MB/s
# ...
#      |████████████████████████████████| 9.7 MB 34.5 MB/s
# ...
#      |████████████████████████████████| 1.7 MB 40.3 MB/s
# ...
#      |████████████████████████████████| 43 kB 2.0 MB/s
# ...
#      |████████████████████████████████| 180 kB 57.8 MB/s
# ...
#      |████████████████████████████████| 144 kB 52.4 MB/s
# ...
#      |████████████████████████████████| 63 kB 1.9 MB/s
# ...

# %%
from simpletransformers.ner import NERModel, NERArgs
import pandas as pd
from google.colab import files

model_args = NERArgs(learning_rate=1e-5, num_train_epochs=4, eval_batch_size=8, train_batch_size=8, weight_decay=1)
model_args.labels_list = ["B-LOC", "I-LOC", "B-ORG", "I-ORG", "B-DATE", "B-PER", "I-PER", "I-DATE", "O"]


model = NERModel(
    "xlmroberta", "xlm-roberta-large", 
    args=model_args,
)
# Out:
# Downloading:   0%|          | 0.00/513 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/2.09G [00:00<?, ?B/s]
# Some weights of the model checkpoint at xlm-roberta-large were not used when initializing XLMRobertaForTokenClassification: ['lm_head.dense.weight', 'lm_head.decoder.weight', 'lm_head.bias', 'lm_head.dense.bias', 'lm_head.layer_norm.bias', 'lm_head.layer_norm.weight']
# - This IS expected if you are initializing XLMRobertaForTokenClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing XLMRobertaForTokenClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# ...

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-2472ead8-4c74-49a6-b732-723e0e0f5577" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2472ead8-4c74-49a6-b732-723e0e0f5577">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving train_lug.txt to train_lug.txt

# %%
def load_train():
  df_text = uploaded['train_lug.txt'].decode("utf-8")
  text = df_text.split('\n\n')

  df_train = pd.DataFrame()
  df_train['sentence_id'] = pd.Series()
  df_train['words'] = pd.Series()
  df_train['labels'] = pd.Series()

  sentence_num = []
  words = []
  tag = []
  for i in range(len(text)):
      sentence = text[i].split('\n')
      for j in range(len(sentence)-1):
          word = sentence[j].split(" ")
          sentence_num.append(i)
          words.append(word[0])
          tag.append(word[1])
     
  df_train['sentence_id'] = sentence_num
  df_train['words'] = words
  df_train['labels'] = tag
  return df_train

# %%
df_train1 = load_train()
df_train1
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   import sys
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#        sentence_id       words labels
# 0                0      Empaka      O
# 1                0  zaakubeera      O
# 2                0          mu      O
# 3                0      kibuga      O
# 4                0   Liverpool  B-LOC
# ...            ...         ...    ...
# ...

# %%
df_train = df_train1.head(5000)
df_test = df_train1.tail(5000)

# %%
model.train_model(df_train)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/transformers/optimization.py:309: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use thePyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
# ...
# Running Epoch 0 of 4:   0%|          | 0/31 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/torch/optim/lr_scheduler.py:134: UserWarning: Detected call of `lr_scheduler.step()` before `optimizer.step()`. In PyTorch 1.1.0 and later, you should call them in the opposite order: `optimizer.step()` before `lr_scheduler.step()`.  Failure to do this will result in PyTorch skipping the first value of the learning rate schedule. See more details at https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate
#   "https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate", UserWarning)
# ...

# %% [markdown]
# # Upload Prediction Text and Predict

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-4cd416fe-d8a1-4d37-9302-38077aff287e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4cd416fe-d8a1-4d37-9302-38077aff287e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving lug_mat_acts.txt to lug_mat_acts.txt

# %%
test_text = uploaded['lug_mat_acts.txt'].decode("utf-8")
test_text = "".join(filter(lambda x: not x.isdigit(), test_text))
text = test_text.split('\n')
new_text = [s.replace("\x0c", "") for s in text]
new_text = [s.replace("\t", "") for s in new_text]

# %%
new_text
# Out:
# ['Matei ',
#  '',
#  ' Lukolo lwa Yesu Kiristu',
#  '',
# ...

# %%
predictions, raw_outputs = model.predict(new_text)
# Out:
# ...
# Running Prediction:   0%|          | 0/242 [00:00<?, ?it/s]

# %%
def new_data():
  id = len(df_train)

  keys = []
  values = []
  sentence_id = []
  for idx in range(len(predictions)):
    for length in range(len(predictions[idx])):
      for key in predictions[idx][length].keys():
        keys.append(key)
        sentence_id.append(id)
      for value in predictions[idx][length].values():
        values.append(value)

    id += 1 

  df_pred = pd.DataFrame({'sentence_id':sentence_id, 'words':keys, 'labels':values})
  df_newTrain = pd.concat([df_train, df_pred])
  df_newTrain.reset_index(inplace=True, drop=True)
  return df_newTrain

# %%
df_newTrain = new_data()
df_newTrain
# Out:
#        sentence_id        words labels
# 0                0       Empaka      O
# 1                0   zaakubeera      O
# 2                0           mu      O
# 3                0       kibuga      O
# 4                0    Liverpool  B-LOC
# ...            ...          ...    ...
# 30994         6933     kupfuka,      O
# 30995         6933           na      O
# 30996         6933       kuduhu      O
# 30997         6933        imunu      O
# 30998         6933  yamghomile.      O
#
# [30999 rows x 3 columns]

# %%
# Out:
# Epoch 51

# %% [markdown]
# # Train 50 Epochs

# %%
for epoch in range(75):

  print(f"Epoch {epoch+1}")
  model_args = NERArgs(learning_rate=1e-5, num_train_epochs=1, eval_batch_size=8, train_batch_size=8, weight_decay=1, overwrite_output_dir=True)
  model_args.labels_list = ["B-LOC", "I-LOC", "B-ORG", "I-ORG", "B-DATE", "B-PER", "I-PER", "I-DATE", "O"]

  model = NERModel(
      "xlmroberta", "/content/outputs/", 
      args=model_args,
  )

  model.train_model(df_newTrain)
  predictions, raw_outputs = model.predict(text)
  df_newTrain = new_data()
# Out:
# Epoch 1
#   0%|          | 0/4 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/transformers/optimization.py:309: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use thePyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
# ...
# Running Prediction:   0%|          | 0/242 [00:00<?, ?it/s]
# Epoch 2
# ...
# Running Prediction:   0%|          | 0/242 [00:00<?, ?it/s]
# Epoch 3
# ...
# Running Prediction:   0%|          | 0/242 [00:00<?, ?it/s]
# Epoch 4
# ...
# Running Prediction:   0%|          | 0/242 [00:00<?, ?it/s]
# Epoch 5
# ...
# Running Prediction:   0%|          | 0/242 [00:00<?, ?it/s]
# Epoch 6
# ...
# Running Prediction:   0%|          | 0/242 [00:00<?, ?it/s]
# Epoch 7
# ...
# Running Prediction:   0%|          | 0/242 [00:00<?, ?it/s]
# Epoch 8
# ...
# Running Prediction:   0%|          | 0/242 [00:00<?, ?it/s]
# Epoch 9
# ...
# Running Prediction:   0%|          | 0/242 [00:00<?, ?it/s]
# ...

# %%
result, model_outputs, wrong_preds = model.eval_model(df_test)
result
# Out:
# ...
# Running Evaluation:   0%|          | 0/29 [00:00<?, ?it/s]
# {'eval_loss': 0.7302111156027893,
#  'f1_score': 0.6821705426356589,
#  'precision': 0.6416666666666667,
#  'recall': 0.7281323877068558}

# %%
from google.colab import files
df_newTrain.to_csv('augmented_train_LUG.csv') 
files.download('augmented_train_LUG.csv')

# %%
df_eval = pd.DataFrame(result, index=[0])
df_eval
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-a15883822396> in <module>()
# ----> 1 df_eval = pd.DataFrame(result, index=[0])
#       2 df_eval
#
# NameError: name 'result' is not defined
